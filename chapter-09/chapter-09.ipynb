# %%
from numpy.random import normal
mu = 50
sigma = 5
n = 10
sample = normal(mu, sigma, n)
print(sample)
# Out:
# [55.47007625 50.34870812 51.80589843 54.51100186 50.11400015 50.01237136
#  53.06575381 54.70009564 46.3961415  47.77771236]

# %%
from scipy.stats import norm
from matplotlib import pyplot
mu = 50
sigma = 5
dist = norm(mu, sigma)
values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]
pyplot.plot(values, probabilities)
pyplot.show()
cprobs = [dist.cdf(value) for value in values]
pyplot.plot(values, cprobs)
pyplot.show()

# %%
from scipy.stats import norm
mu = 50
sigma = 5
dist = norm(mu, sigma)
low_end = dist.ppf(0.025)
high_end = dist.ppf(0.975)
print('Middle 95%% between %.1f and %.1f' % (low_end, high_end))
# Out:
# Middle 95% between 40.2 and 59.8

# %%
from numpy.random import exponential
beta = 50
n = 10
sample = exponential(beta, n)
print(sample)
# Out:
# [196.03586631  38.20601106   0.56092751  27.10335329  69.65011277
#   10.59844796  15.19123499  68.74097746  35.80257963 104.38791612]

# %%
from scipy.stats import expon
from matplotlib import pyplot
beta = 50
dist = expon(beta)
values = [value for value in range(50, 70)]
probabilities = [dist.pdf(value) for value in values]
pyplot.plot(values, probabilities)
pyplot.show()
cprobs = [dist.cdf(value) for value in values]
pyplot.plot(values, cprobs)
pyplot.show()

# %%
from numpy.random import pareto
alpha = 1.1
n = 10
sample = pareto(alpha, n)
print(sample)
# Out:
# [ 0.33165923  0.84593175  0.62115155  3.90365351 96.52225993  0.7604555
#   0.27755233  0.75466447  0.94306973  0.70787988]

# %%
from scipy.stats import pareto
from matplotlib import pyplot
alpha = 1.5
dist = pareto(alpha)
values = [value/10.0 for value in range(10, 100)]
probabilities = [dist.pdf(value) for value in values]
pyplot.plot(values, probabilities)
pyplot.show()
cprobs = [dist.cdf(value) for value in values]
pyplot.plot(values, cprobs)
pyplot.show()
